# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nytimes_dat = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv'
dat = pd.read_csv(nytimes_dat, error_bad_lines=False)

# %%
dat.shape[1]
# Out:
# 5

# %%
dat
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 1381  2020-03-27       Virginia    51    606      14
# 1382  2020-03-27     Washington    53   3770     177
# 1383  2020-03-27  West Virginia    54     96       0
# 1384  2020-03-27      Wisconsin    55    930      16
# 1385  2020-03-27        Wyoming    56     73       0
#
# [1386 rows x 5 columns]

# %%
n=[]
for i in range(dat.shape[0]):
    if dat.iloc[i,1] not in n:
        n.append(dat.iloc[i,1])

# %%
n[5]
# Out:
# 'Wisconsin'

# %%
#for loop to iterate your n 
maxc=0
maxs=''
for f in range(len(n)):
    dat_state = []
    for i in range(dat.shape[0]):
        if dat.iloc[i,1] == n[f]:
            dat_state.append(dat.iloc[i, 3])        
    plt.plot(dat_state)
    plt.ylabel('Test Postive Cases ')
    plt.title(n[f])
    plt.show()
    #compare to maxc and update maxc and maxs if maxc is not bigger than the last element in dat_state
    if maxc < dat_state[len(dat_state)-1]:
        maxc= dat_state[len(dat_state)-1]
        maxs= n[f]

# %%
maxs
# Out:
# 'New York'

# %%
maxc
# Out:
# 44635

# %%
hzk237

# %%
elif f == 'vowels':
            xyz=[]
            for b in range (0,s-1):
                if l[b] in abc:
                    if l[b] not in x:  
                        if l[b] not in xyz:
                            xyz.append(l[b])
            print(xyz)

# %%
n
# Out:
# ['Washington',
#  'Illinois',
#  'California',
#  'Arizona',
#  'Massachusetts',
#  'Wisconsin',
#  'Texas',
#  'Nebraska',
#  'Utah',
#  'Oregon',
#  'Florida',
#  'New York',
#  'Rhode Island',
#  'Georgia',
#  'New Hampshire',
#  'North Carolina',
#  'New Jersey',
#  'Colorado',
#  'Maryland',
#  'Nevada',
#  'Tennessee',
#  'Hawaii',
#  'Indiana',
#  'Kentucky',
#  'Minnesota',
#  'Oklahoma',
#  'Pennsylvania',
#  'South Carolina',
#  'District of Columbia',
#  'Kansas',
#  'Missouri',
#  'Vermont',
#  'Virginia',
#  'Connecticut',
#  'Iowa',
#  'Louisiana',
#  'Ohio',
#  'Michigan',
#  'South Dakota',
#  'Arkansas',
#  'Delaware',
#  'Mississippi',
#  'New Mexico',
#  'North Dakota',
#  'Wyoming',
#  'Alaska',
#  'Maine',
#  'Alabama',
#  'Idaho',
#  'Montana',
#  'Puerto Rico',
#  'Virgin Islands',
#  'Guam',
#  'West Virginia']

# %%
bat[0].split(',')
# Out:
# ['Province/State',
#  'Country/Region',
#  'Lat',
#  'Long',
#  '1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20']

# %%
a='csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'

# %%
https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'

# %%
b='/home/bcao/workspace/ben/lesson/common_3K_words.txt'
fh = open(b,'r')
dat = fh.readlines()
for i in range (0,3000):
    dat[i] = dat[i].strip()
print(dat)
